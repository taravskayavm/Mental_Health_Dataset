# %% [markdown]
# ДЗ 5
#
# Проведите разведочный анализ данных на датасете с kaggle.com

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
plt.rcParams['axes.grid'] = True

# %%
df = pd.read_csv('C:/Users/user/Documents/Blastim/ML_on_Python/Python/Mental Health Dataset.csv')

# %% [markdown]
# About Dataset
#
# This dataset records a global survey conducted to track trends in mental health. The data covers a range of variables such as levels of stress, depression, anxiety, subjective well-being, and use of mental health services. The survey involved respondents from various demographic backgrounds, including gender, employment status, and geographic region. This dataset aims to provide a better understanding of changes in mental health globally over the specified time period.
#
# The studied characteristics of the respondents:
#
# - Timestamp (Time and date of survey)
# - Gender (Gender of the respondent)
# - Country (The country where the respondent lives)
# - Occupation (Occupation or profession of the respondent)
# - self_employed (Is the respondent self-employed or not?)
# - family_history (Is there a history of mental health disorders in the respondent's family?)
# - treatment (Has the respondent ever received treatment or therapy for mental health problems?)
# - Days_Indoors (Estimated number of days a week the respondent spends indoors)
# - Growing_Stress (The current level of stress the respondent feels)
# - Changes_Habits (Has the respondent experienced any changes in sleeping habits or patterns?)

# %%
df
# Out:
#                   Timestamp  Gender        Country Occupation self_employed  \
# 0       2014-08-27 11:29:31  Female  United States  Corporate           NaN
# 1       2014-08-27 11:31:50  Female  United States  Corporate           NaN
# 2       2014-08-27 11:32:39  Female  United States  Corporate           NaN
# 3       2014-08-27 11:37:59  Female  United States  Corporate            No
# 4       2014-08-27 11:43:36  Female  United States  Corporate            No
# ...                     ...     ...            ...        ...           ...
# 292359  2015-07-27 23:25:34    Male  United States   Business           Yes
# 292360  2015-08-17 09:38:35    Male   South Africa   Business            No
# 292361  2015-08-25 19:59:38    Male  United States   Business            No
# 292362  2015-09-26 01:07:35    Male  United States   Business            No
# 292363  2016-02-01 23:04:31    Male  United States   Business            No
#
#        family_history treatment Days_Indoors Growing_Stress Changes_Habits  \
# 0                  No       Yes    1-14 days            Yes             No
# 1                 Yes       Yes    1-14 days            Yes             No
# 2                 Yes       Yes    1-14 days            Yes             No
# 3                 Yes       Yes    1-14 days            Yes             No
# 4                 Yes       Yes    1-14 days            Yes             No
# ...               ...       ...          ...            ...            ...
# 292359            Yes       Yes   15-30 days             No          Maybe
# 292360            Yes       Yes   15-30 days             No          Maybe
# 292361            Yes        No   15-30 days             No          Maybe
# 292362            Yes       Yes   15-30 days             No          Maybe
# 292363            Yes       Yes   15-30 days             No          Maybe
#
#        Mental_Health_History Mood_Swings Coping_Struggles Work_Interest  \
# 0                        Yes      Medium               No            No
# 1                        Yes      Medium               No            No
# 2                        Yes      Medium               No            No
# 3                        Yes      Medium               No            No
# 4                        Yes      Medium               No            No
# ...                      ...         ...              ...           ...
# 292359                    No         Low              Yes            No
# 292360                    No         Low              Yes            No
# 292361                    No         Low              Yes            No
# 292362                    No         Low              Yes            No
# 292363                    No         Low              Yes            No
#
#        Social_Weakness mental_health_interview care_options
# 0                  Yes                      No     Not sure
# 1                  Yes                      No           No
# 2                  Yes                      No          Yes
# 3                  Yes                   Maybe          Yes
# 4                  Yes                      No          Yes
# ...                ...                     ...          ...
# 292359           Maybe                   Maybe     Not sure
# 292360           Maybe                      No          Yes
# 292361           Maybe                      No           No
# 292362           Maybe                      No          Yes
# 292363           Maybe                      No          Yes
#
# [292364 rows x 17 columns]

# %%
df.head() #зачем нужна эта функция, если первые строчки и так видно?
# Out:
#              Timestamp  Gender        Country Occupation self_employed  \
# 0  2014-08-27 11:29:31  Female  United States  Corporate           NaN
# 1  2014-08-27 11:31:50  Female  United States  Corporate           NaN
# 2  2014-08-27 11:32:39  Female  United States  Corporate           NaN
# 3  2014-08-27 11:37:59  Female  United States  Corporate            No
# 4  2014-08-27 11:43:36  Female  United States  Corporate            No
#
#   family_history treatment Days_Indoors Growing_Stress Changes_Habits  \
# 0             No       Yes    1-14 days            Yes             No
# 1            Yes       Yes    1-14 days            Yes             No
# 2            Yes       Yes    1-14 days            Yes             No
# 3            Yes       Yes    1-14 days            Yes             No
# 4            Yes       Yes    1-14 days            Yes             No
#
#   Mental_Health_History Mood_Swings Coping_Struggles Work_Interest  \
# 0                   Yes      Medium               No            No
# 1                   Yes      Medium               No            No
# 2                   Yes      Medium               No            No
# 3                   Yes      Medium               No            No
# 4                   Yes      Medium               No            No
#
#   Social_Weakness mental_health_interview care_options
# 0             Yes                      No     Not sure
# 1             Yes                      No           No
# 2             Yes                      No          Yes
# 3             Yes                   Maybe          Yes
# 4             Yes                      No          Yes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 292364 entries, 0 to 292363
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Timestamp                292364 non-null  object
#  1   Gender                   292364 non-null  object
#  2   Country                  292364 non-null  object
#  3   Occupation               292364 non-null  object
#  4   self_employed            287162 non-null  object
#  5   family_history           292364 non-null  object
#  6   treatment                292364 non-null  object
#  7   Days_Indoors             292364 non-null  object
#  8   Growing_Stress           292364 non-null  object
#  9   Changes_Habits           292364 non-null  object
#  10  Mental_Health_History    292364 non-null  object
#  11  Mood_Swings              292364 non-null  object
#  12  Coping_Struggles         292364 non-null  object
#  13  Work_Interest            292364 non-null  object
#  14  Social_Weakness          292364 non-null  object
#  15  mental_health_interview  292364 non-null  object
#  16  care_options             292364 non-null  object
# dtypes: object(17)
# memory usage: 37.9+ MB

# %%
del df['Timestamp']

# %%
df = df.rename(columns = str.lower)
df
# Out:
#         gender        country occupation self_employed family_history  \
# 0       Female  United States  Corporate           NaN             No
# 1       Female  United States  Corporate           NaN            Yes
# 2       Female  United States  Corporate           NaN            Yes
# 3       Female  United States  Corporate            No            Yes
# 4       Female  United States  Corporate            No            Yes
# ...        ...            ...        ...           ...            ...
# 292359    Male  United States   Business           Yes            Yes
# 292360    Male   South Africa   Business            No            Yes
# 292361    Male  United States   Business            No            Yes
# 292362    Male  United States   Business            No            Yes
# 292363    Male  United States   Business            No            Yes
#
#        treatment days_indoors growing_stress changes_habits  \
# 0            Yes    1-14 days            Yes             No
# 1            Yes    1-14 days            Yes             No
# 2            Yes    1-14 days            Yes             No
# 3            Yes    1-14 days            Yes             No
# 4            Yes    1-14 days            Yes             No
# ...          ...          ...            ...            ...
# 292359       Yes   15-30 days             No          Maybe
# 292360       Yes   15-30 days             No          Maybe
# 292361        No   15-30 days             No          Maybe
# 292362       Yes   15-30 days             No          Maybe
# 292363       Yes   15-30 days             No          Maybe
#
#        mental_health_history mood_swings coping_struggles work_interest  \
# 0                        Yes      Medium               No            No
# 1                        Yes      Medium               No            No
# 2                        Yes      Medium               No            No
# 3                        Yes      Medium               No            No
# 4                        Yes      Medium               No            No
# ...                      ...         ...              ...           ...
# 292359                    No         Low              Yes            No
# 292360                    No         Low              Yes            No
# 292361                    No         Low              Yes            No
# 292362                    No         Low              Yes            No
# 292363                    No         Low              Yes            No
#
#        social_weakness mental_health_interview care_options
# 0                  Yes                      No     Not sure
# 1                  Yes                      No           No
# 2                  Yes                      No          Yes
# 3                  Yes                   Maybe          Yes
# 4                  Yes                      No          Yes
# ...                ...                     ...          ...
# 292359           Maybe                   Maybe     Not sure
# 292360           Maybe                      No          Yes
# 292361           Maybe                      No           No
# 292362           Maybe                      No          Yes
# 292363           Maybe                      No          Yes
#
# [292364 rows x 16 columns]

# %%
df.isnull().sum()
# Out:
# gender                        0
# country                       0
# occupation                    0
# self_employed              5202
# family_history                0
# treatment                     0
# days_indoors                  0
# growing_stress                0
# changes_habits                0
# mental_health_history         0
# mood_swings                   0
# coping_struggles              0
# work_interest                 0
# social_weakness               0
# mental_health_interview       0
# care_options                  0
# dtype: int64

# %%
df = df.dropna(subset = 'self_employed')

# %%
df.nunique()
# Out:
# gender                      2
# country                    35
# occupation                  5
# self_employed               2
# family_history              2
# treatment                   2
# days_indoors                5
# growing_stress              3
# changes_habits              3
# mental_health_history       3
# mood_swings                 3
# coping_struggles            2
# work_interest               3
# social_weakness             3
# mental_health_interview     3
# care_options                3
# dtype: int64

# %%
df["country"].unique()
# Out:
# array(['United States', 'Poland', 'Australia', 'Canada', 'United Kingdom',
#        'South Africa', 'Sweden', 'New Zealand', 'Netherlands', 'India',
#        'Belgium', 'Ireland', 'France', 'Portugal', 'Brazil', 'Costa Rica',
#        'Russia', 'Germany', 'Switzerland', 'Finland', 'Israel', 'Italy',
#        'Bosnia and Herzegovina', 'Singapore', 'Nigeria', 'Croatia',
#        'Thailand', 'Denmark', 'Mexico', 'Greece', 'Moldova', 'Colombia',
#        'Georgia', 'Czech Republic', 'Philippines'], dtype=object)

# %%
df['country'].value_counts()
# Out:
# country
# United States             168056
# United Kingdom             50624
# Canada                     17556
# Australia                   6026
# Netherlands                 5894
# Ireland                     5548
# Germany                     4680
# Sweden                      2818
# India                       2774
# France                      2340
# Brazil                      2340
# New Zealand                 1994
# South Africa                1994
# Switzerland                 1560
# Israel                      1560
# Italy                       1560
# Belgium                      824
# Poland                       824
# Russia                       780
# Denmark                      780
# Singapore                    780
# Greece                       780
# Czech Republic               390
# Georgia                      390
# Colombia                     390
# Moldova                      390
# Mexico                       390
# Croatia                      390
# Thailand                     390
# Nigeria                      390
# Bosnia and Herzegovina       390
# Portugal                     390
# Finland                      390
# Costa Rica                   390
# Philippines                  390
# Name: count, dtype: int64

# %%
df['country'].value_counts(normalize=True)
# Out:
# country
# United States             0.585231
# United Kingdom            0.176291
# Canada                    0.061136
# Australia                 0.020985
# Netherlands               0.020525
# Ireland                   0.019320
# Germany                   0.016297
# Sweden                    0.009813
# India                     0.009660
# France                    0.008149
# Brazil                    0.008149
# New Zealand               0.006944
# South Africa              0.006944
# Switzerland               0.005432
# Israel                    0.005432
# Italy                     0.005432
# Belgium                   0.002869
# Poland                    0.002869
# Russia                    0.002716
# Denmark                   0.002716
# Singapore                 0.002716
# Greece                    0.002716
# Czech Republic            0.001358
# Georgia                   0.001358
# Colombia                  0.001358
# Moldova                   0.001358
# Mexico                    0.001358
# Croatia                   0.001358
# Thailand                  0.001358
# Nigeria                   0.001358
# Bosnia and Herzegovina    0.001358
# Portugal                  0.001358
# Finland                   0.001358
# Costa Rica                0.001358
# Philippines               0.001358
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(13, 10))
sns.set_context("paper", font_scale=0.94)

sns.histplot(
    data=df,
    x='country',
    bins=10,
    hue='country'
)

plt.title('Distribution of the number of respondents by country', fontsize=12)
plt.ylabel('Тumber of respondents', fontsize=12)
plt.xlabel('Country', fontsize=12)
# plt.legend().remove()

bins=10
plt.xticks(rotation=90)

plt.yscale('log')

# %%
df["growing_stress"].unique()
# Out:
# array(['Yes', 'No', 'Maybe'], dtype=object)

# %%
df['growing_stress'].value_counts()
# Out:
# growing_stress
# Maybe    98225
# Yes      97854
# No       91083
# Name: count, dtype: int64

# %%
df['growing_stress'].value_counts(normalize=True)
# Out:
# growing_stress
# Maybe    0.342054
# Yes      0.340762
# No       0.317183
# Name: proportion, dtype: float64

# %%
df["mood_swings"].unique()
# Out:
# array(['Medium', 'Low', 'High'], dtype=object)

# %%
df['mood_swings'].value_counts()
# Out:
# mood_swings
# Medium    99272
# Low       98062
# High      89828
# Name: count, dtype: int64

# %%
df['mood_swings'].value_counts(normalize=True)
# Out:
# mood_swings
# Medium    0.345700
# Low       0.341487
# High      0.312813
# Name: proportion, dtype: float64

# %%
df["treatment"].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['treatment'].value_counts()
# Out:
# treatment
# Yes    144744
# No     142418
# Name: count, dtype: int64

# %%
df['treatment'].value_counts(normalize=True)
# Out:
# treatment
# Yes    0.50405
# No     0.49595
# Name: proportion, dtype: float64

# %%
df['occupation'].unique()
# Out:
# array(['Corporate', 'Student', 'Business', 'Housewife', 'Others'],
#       dtype=object)

# %%
df['occupation'].value_counts()
# Out:
# occupation
# Housewife    65173
# Student      60687
# Corporate    60157
# Others       51893
# Business     49252
# Name: count, dtype: int64

# %%
df['occupation'].value_counts(normalize=True)
# Out:
# occupation
# Housewife    0.226956
# Student      0.211334
# Corporate    0.209488
# Others       0.180710
# Business     0.171513
# Name: proportion, dtype: float64

# %%
df['gender'].value_counts()
# Out:
# gender
# Male      235950
# Female     51212
# Name: count, dtype: int64

# %%
df['gender'].value_counts(normalize=True)
# Out:
# gender
# Male      0.821662
# Female    0.178338
# Name: proportion, dtype: float64

# %%
labels = ['Male', 'Female']
sizes = [0.821662, 0.178338]
colors = ['#66b3ff', '#ff9999']  # Цвета для каждой категории
explode = (0.1, 0)  # Выделение сегмента для "No"

# Построение круговой диаграммы
plt.figure(figsize=(5, 5))
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140, textprops={'fontsize': 12})
plt.axis('equal')  # Позволяет создать круговую диаграмму в виде круга
plt.title('Gender proportion', fontsize=15)
# Out:
# Text(0.5, 1.0, 'Gender proportion')

# %%
df['treatment'].value_counts()
# Out:
# treatment
# Yes    144744
# No     142418
# Name: count, dtype: int64

# %%
df['treatment'].value_counts(normalize=True)
# Out:
# treatment
# Yes    0.50405
# No     0.49595
# Name: proportion, dtype: float64

# %%
df['self_employed'].value_counts()
# Out:
# self_employed
# No     257994
# Yes     29168
# Name: count, dtype: int64

# %%
df['self_employed'].value_counts(normalize=True)
# Out:
# self_employed
# No     0.898427
# Yes    0.101573
# Name: proportion, dtype: float64

# %%
labels = ['No', 'Yes']
sizes = [0.898427, 0.101573]
colors = ['#9370DB', '#F0E68C']  # Цвета для каждой категории
explode = (0.1, 0)  # Выделение сегмента для "No"

# Построение круговой диаграммы
plt.figure(figsize=(5, 5))
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140, textprops={'fontsize': 12})
plt.axis('equal')  # Позволяет создать круговую диаграмму в виде круга
plt.title('Self-employed respondent proportion', fontsize=14)
# Out:
# Text(0.5, 1.0, 'Self-employed respondent proportion')

# %%
# Группировка и подсчет количества ответов по переменной growing_stress и country
stress_by_country = df.groupby(['growing_stress', 'country']).size().unstack()

# Группировка и подсчет количества ответов по переменной growing_stress и gender
stress_by_gender = df.groupby(['growing_stress', 'gender']).size().unstack()

# Группировка и подсчет количества ответов по переменной mood_swings и gender
mood_by_gender = df.groupby(['mood_swings', 'gender']).size().unstack()

# Группировка и подсчет количества ответов по переменной social_weakness и gender
social_weakness_by_gender = df.groupby(['social_weakness', 'gender']).size().unstack()

# Группировка и подсчет количества ответов по переменной treatment и gender
treatment_by_gender = df.groupby(['treatment', 'gender']).size().unstack()

# Группировка и подсчет количества ответов по переменной growing_stress и occupation
stress_by_occupation = df.groupby(['growing_stress', 'occupation']).size().unstack()

# Группировка и подсчет количества ответов по переменной growing_stress и self_employed
stress_by_self_employed = df.groupby(['growing_stress', 'self_employed']).size().unstack()

# Группировка и подсчет количества ответов по переменной Mood_Swings и treatment
mood_by_treatment = df.groupby(['mood_swings', 'treatment']).size().unstack()

# %%
stress_by_country
# Out:
# country         Australia  Belgium  Bosnia and Herzegovina  Brazil  Canada  \
# growing_stress
# Maybe                2027      267                     137     822    5965
# No                   1899      256                     125     750    5554
# Yes                  2100      301                     128     768    6037
#
# country         Colombia  Costa Rica  Croatia  Czech Republic  Denmark  ...  \
# growing_stress                                                          ...
# Maybe                137         137      137             137      274  ...
# No                   125         125      125             125      250  ...
# Yes                  128         128      128             128      256  ...
#
# country         Poland  Portugal  Russia  Singapore  South Africa  Sweden  \
# growing_stress
# Maybe              267       137     274        274           678     945
# No                 256       125     250        250           631     887
# Yes                301       128     256        256           685     986
#
# country         Switzerland  Thailand  United Kingdom  United States
# growing_stress
# Maybe                   548       137           17424          57261
# No                      500       125           16096          53224
# Yes                     512       128           17104          57571
#
# [3 rows x 35 columns]

# %%
plt.figure(figsize=(16, 8))
colors = sns.color_palette("hls", 8)

sns.countplot(data=df, 
              x='country', 
              hue='growing_stress',
              palette=colors)

plt.title('Growing stress in different countries', fontsize=20)
plt.ylabel('Number of responses', fontsize=15)
plt.xlabel('Country', fontsize=15)

bins=25
plt.xticks(rotation=90, ha='right', fontsize=13)
plt.legend(title='Growing Stress', title_fontsize='large', fontsize='large')
plt.yscale('log')

# %%
stress_by_gender
# Out:
# gender          Female   Male
# growing_stress
# Maybe            15340  82885
# No               15458  75625
# Yes              20414  77440

# %%
plt.figure(figsize=(16, 8))
colors = sns.cubehelix_palette(reverse=True, rot=.3)

sns.countplot(data=df, 
              x='gender', 
              hue='growing_stress',
              palette=colors)

plt.title('Growing stress and gender', fontsize=30)
plt.ylabel('Number of responses', fontsize=20)
plt.xlabel('Gender', fontsize=20)

bins=15
plt.xticks(ha='right', fontsize=15)
plt.legend(title='Growing Stress', title_fontsize=13, fontsize=13)

# %%
mood_by_gender
# Out:
# gender       Female   Male
# mood_swings
# High          17228  72600
# Low           16992  81070
# Medium        16992  82280

# %%
plt.figure(figsize=(16, 8))
colors = sns.color_palette("flare", 8)

sns.countplot(data=df, 
              x='gender', 
              hue='mood_swings',
              palette=colors)

plt.title('Mood swings and gender', fontsize=20)
plt.ylabel('Number of responses', fontsize=15)
plt.xlabel('Gender', fontsize=15)

bins=15
plt.xticks(ha='right', fontsize=13)
plt.legend(title='Mood Swings', title_fontsize='large', fontsize='large')

# %%
social_weakness_by_gender
# Out:
# gender           Female   Male
# social_weakness
# Maybe             17464  84095
# No                17582  78045
# Yes               16166  73810

# %%
plt.figure(figsize=(16, 8))
colors = sns.mpl_palette("plasma")

sns.countplot(data=df, 
              x='gender', 
              hue='social_weakness',
              palette=colors)

plt.title('Social weakness and gender', fontsize=20)
plt.ylabel('Number of responses', fontsize=15)
plt.xlabel('Gender', fontsize=15)

bins=15
plt.xticks(ha='right', fontsize=13)
plt.legend(title='Social Weakness', title_fontsize='large', fontsize='large')

# %%
treatment_by_gender
# Out:
# gender     Female    Male
# treatment
# No          16058  126360
# Yes         35154  109590

# %%
plt.figure(figsize=(16, 8))
colors = sns.color_palette("Set1", 8)

sns.countplot(data=df, 
              x='gender', 
              hue='treatment',
              palette=colors)

plt.title('Treatment and gender', fontsize=20)
plt.ylabel('Number of responses', fontsize=15)
plt.xlabel('Gender', fontsize=15)

bins=15
plt.xticks(ha='right', fontsize=13)
plt.legend(title='Treatment', title_fontsize='large', fontsize='large')

# %%
stress_by_occupation
# Out:
# occupation      Business  Corporate  Housewife  Others  Student
# growing_stress
# Maybe              16747      16747      23741   18075    22915
# No                 13958      19905      22192   18680    16348
# Yes                18547      23505      19240   15138    21424

# %%
plt.figure(figsize=(16, 8))
colors = sns.cubehelix_palette(reverse=True, rot=.6)

sns.countplot(data=df, 
              x='occupation', 
              hue='growing_stress',
              palette=colors)

plt.title('Growing stress and occupation', fontsize=20)
plt.ylabel('Number of responses', fontsize=15)
plt.xlabel('Occupation', fontsize=15)

bins=25
plt.xticks(ha='right', fontsize=13)
plt.legend(title='Growing Stress', title_fontsize='large', fontsize='large')

# %%
stress_by_self_employed
# Out:
# self_employed      No    Yes
# growing_stress
# Maybe           88136  10089
# No              81791   9292
# Yes             88067   9787

# %%
plt.figure(figsize=(16, 8))
colors = sns.husl_palette(8, h=.6)

sns.countplot(data=df, 
              x='self_employed', 
              hue='growing_stress',
              palette=colors)

plt.title('Growing stress and self-employed', fontsize=20)
plt.ylabel('Number of responses', fontsize=15)
plt.xlabel('Self employed', fontsize=15)

bins=25
plt.xticks(ha='right', fontsize=13)
plt.legend(title='Growing Stress', title_fontsize='large', fontsize='large')

# %%
mood_by_treatment
# Out:
# treatment       No    Yes
# mood_swings
# High         44282  45546
# Low          48744  49318
# Medium       49392  49880

# %%
plt.figure(figsize=(16, 8))
colors = sns.color_palette("pastel", 8)

sns.countplot(data=df, 
              x='mood_swings', 
              hue='treatment',
              palette=colors)

plt.title('Mood swings and treatment', fontsize=20)
plt.ylabel('Number of responses', fontsize=15)
plt.xlabel('Mood swings', fontsize=15)

bins=25
plt.xticks(ha='right', fontsize=13)
plt.legend(title='Treatment', title_fontsize='large', fontsize='large')
